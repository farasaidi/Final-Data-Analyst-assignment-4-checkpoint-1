# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import numpy as np
df_day = pd.read_csv("day.csv")
df_hour = pd.read_csv("hour.csv")

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# checking for missing data on the HOUR file
df_hour.isna().sum() # the result shows there is no any missing data
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# checking for missing data on the DAY file
df_day.isna().sum() # the result shows there is no any missing data
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
df_hour.describe()
# Looking at the min and max of the columns - there does not seem to be any outliers in correlation to the variables
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
df_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df_hour.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
df_plot = df_hour.hist(figsize=(10,12))

# %%
df_day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
df_day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df_day.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
df_plot = df_day.hist(figsize=(10,12))

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
df_plot = df_day['cnt'].hist(figsize=(10,6))

# %%
# Data Preperation The data to be cleaned interms of parameters before creating the models.
#rename the columns
df = df_hour
df.rename(columns={'dteday':'Date','yr':'Year','mnth':'month','hum':'humidity','cnt':'count'},inplace =True)
df.head()
# Out:
#    instant        Date  season  Year  month  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1     0      1   0        0        6           0
# 1        2  2011-01-01       1     0      1   1        0        6           0
# 2        3  2011-01-01       1     0      1   2        0        6           0
# 3        4  2011-01-01       1     0      1   3        0        6           0
# 4        5  2011-01-01       1     0      1   4        0        6           0
#
#    weathersit  temp   atemp  humidity  windspeed  casual  registered  count
# 0           1  0.24  0.2879      0.81        0.0       3          13     16
# 1           1  0.22  0.2727      0.80        0.0       8          32     40
# 2           1  0.22  0.2727      0.80        0.0       5          27     32
# 3           1  0.24  0.2879      0.75        0.0       3          10     13
# 4           1  0.24  0.2879      0.75        0.0       0           1      1

# %%
# Checking for outliers
# Calculate z-scores for the 'count' column
z_scores = np.abs((df['count'] - df['count'].mean()) / df['count'].std())

# Define a threshold for outlier detection (e.g., z-score > 3)
threshold = 3.5

# Identify outliers based on the threshold
outliers = df[z_scores > threshold]

# Print the outliers
outliers
# Out:
#        instant        Date  season  Year  month  hr  holiday  weekday  \
# 10622    10623  2012-03-23       2     1      3  17        0        5
# 10623    10624  2012-03-23       2     1      3  18        0        5
# 11916    11917  2012-05-16       2     1      5  17        0        3
# 11917    11918  2012-05-16       2     1      5  18        0        3
# 11940    11941  2012-05-17       2     1      5  17        0        4
# ...        ...         ...     ...   ...    ...  ..      ...      ...
# 15756    15757  2012-10-23       4     1     10  17        0        2
# 15757    15758  2012-10-23       4     1     10  18        0        2
# 15780    15781  2012-10-24       4     1     10  17        0        3
# 15781    15782  2012-10-24       4     1     10  18        0        3
# 15804    15805  2012-10-25       4     1     10  17        0        4
#
#        workingday  weathersit  temp   atemp  humidity  windspeed  casual  \
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
#mapping the vars - season,month,weathersit,weekday
df['season']=df.season.map({1: 'spring', 2: 'summer',3:'fall', 4:'winter'})
df['month']=df.month.map({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'June',7:'July',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})
df['weathersit']=df.weathersit.map({1: 'Clear',2:'Mist + Cloudy',3:'Light Snow',4:'Snow + Fog'})
df['weekday']=df.weekday.map({0:'Sun',1:'Mon',2:'Tue',3:'Wed',4:'Thu',5:'Fri',6:'Sat'})
df.head()
# Out:
#    instant        Date  season  Year month  hr  holiday weekday  workingday  \
# 0        1  2011-01-01  spring     0   Jan   0        0     Sat           0
# 1        2  2011-01-01  spring     0   Jan   1        0     Sat           0
# 2        3  2011-01-01  spring     0   Jan   2        0     Sat           0
# 3        4  2011-01-01  spring     0   Jan   3        0     Sat           0
# 4        5  2011-01-01  spring     0   Jan   4        0     Sat           0
#
#   weathersit  temp   atemp  humidity  windspeed  casual  registered  count
# 0      Clear  0.24  0.2879      0.81        0.0       3          13     16
# 1      Clear  0.22  0.2727      0.80        0.0       8          32     40
# 2      Clear  0.22  0.2727      0.80        0.0       5          27     32
# 3      Clear  0.24  0.2879      0.75        0.0       3          10     13
# 4      Clear  0.24  0.2879      0.75        0.0       0           1      1

# %%
# Check for missing values
df.isnull().sum()
# Out:
# instant       0
# Date          0
# season        0
# Year          0
# month         0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
# Check numerical columns for inconsistencies
# Example: Ensure 'temp' column values fall within a valid temperature range
invalid_temp_values = df[(df['temp'] < 0) | (df['temp'] > 1)]
if not invalid_temp_values.empty:
    print("Inconsistent values found in 'temp' column:")
    print(invalid_temp_values)

# %%
# Check categorical columns for inconsistencies
# Example: Ensure 'season' column only contains valid season names
invalid_season_values = df[~df['season'].isin(['spring', 'summer', 'fall', 'winter'])]
if not invalid_season_values.empty:
    print("Inconsistent values found in 'season' column:")
    print(invalid_season_values)

# %%
# Address missing values (if any)
# Example: Replace missing values in 'windspeed' column with the mean
mean_windspeed = df['windspeed'].mean()
df['windspeed'].fillna(mean_windspeed, inplace=True)

# %%
# Address inconsistent values (if any)
# Example: Replace incorrect 'temp' values below 0 with 0
df.loc[df['temp'] < 0, 'temp'] = 0

# %%
# Check the dataset again after addressing inconsistencies
df.head(10)
# Out:
#    instant        Date  season  Year month  hr  holiday weekday  workingday  \
# 0        1  2011-01-01  spring     0   Jan   0        0     Sat           0
# 1        2  2011-01-01  spring     0   Jan   1        0     Sat           0
# 2        3  2011-01-01  spring     0   Jan   2        0     Sat           0
# 3        4  2011-01-01  spring     0   Jan   3        0     Sat           0
# 4        5  2011-01-01  spring     0   Jan   4        0     Sat           0
# 5        6  2011-01-01  spring     0   Jan   5        0     Sat           0
# 6        7  2011-01-01  spring     0   Jan   6        0     Sat           0
# 7        8  2011-01-01  spring     0   Jan   7        0     Sat           0
# 8        9  2011-01-01  spring     0   Jan   8        0     Sat           0
# 9       10  2011-01-01  spring     0   Jan   9        0     Sat           0
#
#       weathersit  temp   atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
#
# No, I did not find all types of dirty data. The data set itsetself was already clean.
#
# 2. Did the process of cleaning your data give you new insights into your dataset?
#
# Using the z-score and a threshold of 3.5, there seems to be over 100 outliers in the 'count' column of the dataset. but based on the histogram visualization, I wouldn't consider them true outlers and chose to not remove them.
#
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
#
# Based on the code results, there doesn't seem to be any obvious inconsistencies in the dataset. All the columns appear to have consistent values, and the code's output confirms that there are no missing values in any of the columns. Therefore, the dataset appears to be consistent and ready for further analysis.
